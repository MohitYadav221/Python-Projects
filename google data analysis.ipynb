# %%
pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\lenovo\anaconda3\lib\site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytrends) (2.32.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\lenovo\anaconda3\lib\site-packages (from pytrends) (2.3.3)
# Requirement already satisfied: lxml in c:\users\lenovo\anaconda3\lib\site-packages (from pytrends) (5.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pytrends.request import TrendReq

# %%
df = pd.read_csv('data-export (1).csv')

# %%
df
# Out:
#              # ----------------------------------------  \
# 0     Session primary channel group (Default channel...
# 1                                                Direct
# 2                                        Organic Social
# 3                                                Direct
# 4                                        Organic Social
# ...                                                 ...
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
# 3182                                         Unassigned
#
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0     Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                   2024041623        237        300               144
# 2                   2024041719        208        267               132
# 3                   2024041723        188        233               115
# 4                   2024041718        187        256               125
# ...                        ...        ...        ...               ...
# 3178                2024042806          0          1                 0
# 3179                2024043005          0          1                 0
# 3180                2024043006          0          1                 0
# 3181                2024050105          0          1                 0
# 3182                2024050307          0          1                 0
#
#                                Unnamed: 5                 Unnamed: 6  \
# 0     Average engagement time per session  Engaged sessions per user
# 1                      47.526666666666700         0.6075949367088610
# 2                       32.09737827715360         0.6346153846153850
# 3                       39.93991416309010         0.6117021276595740
# 4                             32.16015625         0.6684491978609630
# ...                                   ...                        ...
# 3178                                    0                          0
# 3179                                    0                          0
# 3180                                    0                          0
# 3181                                    0                          0
# 3182                                    0                          0
#
#               Unnamed: 7           Unnamed: 8   Unnamed: 9
# 0     Events per session      Engagement rate  Event count
# 1      4.673333333333330                 0.48         1402
# 2      4.295880149812730   0.4943820224719100         1147
# 3      4.587982832618030  0.49356223175965700         1069
# 4               4.078125           0.48828125         1044
# ...                  ...                  ...          ...
# 3178                   2                    0            2
# 3179                   2                    0            2
# 3180                   2                    0            2
# 3181                   2                    0            2
# 3182                   2                    0            2
#
# [3183 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 10 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   # ----------------------------------------  3183 non-null   object
#  1   Unnamed: 1                                  3183 non-null   object
#  2   Unnamed: 2                                  3183 non-null   object
#  3   Unnamed: 3                                  3183 non-null   object
#  4   Unnamed: 4                                  3183 non-null   object
#  5   Unnamed: 5                                  3183 non-null   object
#  6   Unnamed: 6                                  3183 non-null   object
#  7   Unnamed: 7                                  3183 non-null   object
#  8   Unnamed: 8                                  3183 non-null   object
#  9   Unnamed: 9                                  3183 non-null   object
# dtypes: object(10)
# memory usage: 248.8+ KB

# %%
df.describe()
# Out:
#        # ----------------------------------------  Unnamed: 1 Unnamed: 2  \
# count                                        3183        3183       3183
# unique                                          8         673        148
# top                                        Direct  2024042417          1
# freq                                          672           6        335
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# count        3183       3183       3183       3183       3183       3183
# unique        181        104       2824        809       2026        987
# top             1          0          0          0          1          0
# freq          340        393        170        393        133        393
#
#        Unnamed: 9
# count        3183
# unique        679
# top             1
# freq          115

# %%
df.isnull().sum()
# Out:
# # ----------------------------------------    0
# Unnamed: 1                                    0
# Unnamed: 2                                    0
# Unnamed: 3                                    0
# Unnamed: 4                                    0
# Unnamed: 5                                    0
# Unnamed: 6                                    0
# Unnamed: 7                                    0
# Unnamed: 8                                    0
# Unnamed: 9                                    0
# dtype: int64

# %% [markdown]
# # PyTrends Setup aur Keyword Define Karna

# %%
pytrends = TrendReq(hl = 'en-US', tz = 360)
keyword = 'cloud computing'

# %% [markdown]
#  # Data Request Karna

# %%
pytrands.build_payload([keyword], cat= 0, timeframe ='today 12-m',
                       geo='', gprop='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pytrands.build_payload([keyword], cat= 0, timeframe ='today 12-m',
#       2                        geo='', gprop='')
#
# NameError: name 'pytrands' is not defined

# %% [markdown]
# # country-wise Interest Nikalna

# %%
region_data = pytrends.interest_by_region()
region_data = region_data.sort_values(by=keyword, ascending=False).head(15)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 region_data = pytrends.interest_by_region()
#       2 region_data = region_data.sort_values(by=keyword, ascending=False).head(15)
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:340, in TrendReq.interest_by_region(self, resolution, inc_low_vol, inc_geo_code)
#     337 region_payload['tz'] = self.tz
#     339 # parse returned json
# --> 340 req_json = self._get_data(
#     341     url=TrendReq.INTEREST_BY_REGION_URL,
#     342     method=TrendReq.GET_METHOD,
#     343     trim_chars=5,
#     344     params=region_payload,
#     345 )
#     346 df = pd.DataFrame(req_json['default']['geoMapData'])
#     347 if (df.empty):
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:159, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     157 else:
#     158     if response.status_code == status_codes.codes.too_many_requests:
# --> 159         raise exceptions.TooManyRequestsError.from_response(response)
#     160     raise exceptions.ResponseError.from_response(response)
#
# TooManyRequestsError: The request failed: Google returned a response with code 429

# %% [markdown]
# # Bar Plot Banana (Top Countries):

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=region_data[keyword], y=region_data.index, palette='Blues_d')
plt.title(f"Top Countries Searching '{keyword}'")
plt.xlabel("Interest")
plt.ylabel("Country")
plt.show()

# %% [markdown]
# # choropleth (World Map Plot):

# %%
region_data = region_data.reset_index()
fig = px.choropleth(region_data, 
                    locations='geoName',
                    locationmode='country names',
                    color=keyword,
                    title=f"Search Interest for '{keyword}' by Country",
                    color_continuous_scale='Blues')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 region_data = region_data.reset_index()
#       2 fig = px.choropleth(region_data,
#       3                     locations='geoName',
#       4                     locationmode='country names',
#       5                     color=keyword,
#       6                     title=f"Search Interest for '{keyword}' by Country",
#       7                     color_continuous_scale='Blues')
#       8 fig.show()
#
# NameError: name 'region_data' is not defined

# %% [markdown]
# # Time-wise Interest Nikalna:

# %%
time_df = pytrends.interest_over_time()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 time_df = pytrends.interest_over_time()
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:232, in TrendReq.interest_over_time(self)
#     224 over_time_payload = {
#     225     # convert to string as requests will mangle
#     226     'req': json.dumps(self.interest_over_time_widget['request']),
#     227     'token': self.interest_over_time_widget['token'],
#     228     'tz': self.tz
#     229 }
#     231 # make the request and parse the returned json
# --> 232 req_json = self._get_data(
#     233     url=TrendReq.INTEREST_OVER_TIME_URL,
#     234     method=TrendReq.GET_METHOD,
#     235     trim_chars=5,
#     236     params=over_time_payload,
#     237 )
#     239 df = pd.DataFrame(req_json['default']['timelineData'])
#     240 if (df.empty):
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:159, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     157 else:
#     158     if response.status_code == status_codes.codes.too_many_requests:
# --> 159         raise exceptions.TooManyRequestsError.from_response(response)
#     160     raise exceptions.ResponseError.from_response(response)
#
# TooManyRequestsError: The request failed: Google returned a response with code 429

# %% [markdown]
# # line Plot (Search Trend Over Time)

# %%
plt.figure(figsize=(12,6))
plt.plot(time_df.index, time_df[keyword], marker='o', color='purple')
plt.title(f"Search Interest Over Time for '{keyword}'")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.grid(True)
plt.xticks(rotation=45)

# %%
plt.tight_layout()
plt.show()

# %% [markdown]
# # Multiple Keywords Compare Karna

# %%
kw_list = ["cloud computing", "data science", "machine learning"]
pytrends.build_payload(kw_list, cat=0, timeframe='today 12-m', geo='', gprop='')

# %% [markdown]
# # Comparison Plot (Line Plot of All 3 Keywords)

# %%
compare_df = pytrends.interest_over_time()
plt.figure(figsize=(12,6))
for kw in kw_list:
    plt.plot(compare_df.index, compare_df[kw], label=kw)
plt.title("Keyword Comparison Over Time")
plt.xlabel("Date")
plt.ylabel("Search Interest")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 compare_df = pytrends.interest_over_time()
#       2 plt.figure(figsize=(12,6))
#       3 for kw in kw_list:
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:232, in TrendReq.interest_over_time(self)
#     224 over_time_payload = {
#     225     # convert to string as requests will mangle
#     226     'req': json.dumps(self.interest_over_time_widget['request']),
#     227     'token': self.interest_over_time_widget['token'],
#     228     'tz': self.tz
#     229 }
#     231 # make the request and parse the returned json
# --> 232 req_json = self._get_data(
#     233     url=TrendReq.INTEREST_OVER_TIME_URL,
#     234     method=TrendReq.GET_METHOD,
#     235     trim_chars=5,
#     236     params=over_time_payload,
#     237 )
#     239 df = pd.DataFrame(req_json['default']['timelineData'])
#     240 if (df.empty):
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:159, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     157 else:
#     158     if response.status_code == status_codes.codes.too_many_requests:
# --> 159         raise exceptions.TooManyRequestsError.from_response(response)
#     160     raise exceptions.ResponseError.from_response(response)
#
# TooManyRequestsError: The request failed: Google returned a response with code 429
